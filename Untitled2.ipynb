# %% [markdown]
# <a href="https://colab.research.google.com/github/hamnafathimak/pythons1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def abcd(a,b):
  return a+b
  abcd(1,2)

# %%
abcd(1,2)
# Out:
# 3

# %%
def abcd(a,b):
  return a-b

# %%
abcd(1,2)
# Out:
# -1

# %%
def abcd(animal,name):
 print(f"I have a {animal} and it's called {name}")

# %%
def abcd(*numbers):
 return sum (numbers)

# %%
abcd(1,2,3,4,5)
# Out:
# 15

# %%
def abcd(*numbers):
  print(type(numbers))
  print (numbers)
  return sum (numbers)

# %%
abcd(1,2,3,4,5)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5)
# 15

# %%
print("I have a cat {animal} and it's name is tom")
# Out:
# I have a cat {animal} and it's name is tom
