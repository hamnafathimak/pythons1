# %% [markdown]
# <a href="https://colab.research.google.com/github/HamnaFathima03/pythons1/blob/main/data_grouping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,7):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in (5):
  print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4048206415.py in <cell line: 0>()
# ----> 1 for i in (5):
#       2   print(i)
#
# TypeError: 'int' object is not iterable

# %%
haisi=[1,2,3,4]
print(haisi)
# Out:
# [1, 2, 3, 4]

# %%
hasi=[1,2,3,4]
hasi.append(5)
print(hasi)
# Out:
# [1, 2, 3, 4, 5]

# %%
hasi=[1,2,3,4]
hasi.append(5)
hasi.remove(5)
print(hasi)
# Out:
# [1, 2, 3, 4]

# %%
hasi=[1,2,3,4]
hasi.insert(5)
print(hasi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3328142820.py in <cell line: 0>()
#       1 hasi=[1,2,3,4]
# ----> 2 hasi.insert(5)
#       3 print(hasi)
#
# TypeError: insert expected 2 arguments, got 1

# %%
animal=["a,b,c,d"]
print(animal)
# Out:
# ['a,b,c,d']

# %%
animal=["a","b","c","d"]
print(animal)
animal.insert(5,"e")
print(animal)
# Out:
# ['a', 'b', 'c', 'd']
# ['a', 'b', 'c', 'd', 'e']

# %%
animal=("a","b","c","d")
print(animal)
# Out:
# ('a', 'b', 'c', 'd')

# %%
for hasi in["a","b","c"]:
 print (hasi)
# Out:
# a
# b
# c
