# %% [markdown]
# <a href="https://colab.research.google.com/github/hamnafathimak/pythons1/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hamna():
 print("hello")

# %%
hamna()
# Out:
# hello

# %%
def hamna(a,b):
  print(a+b)

# %%
hamna(3,4)
# Out:
# 7

# %%
def hamna(a,b):
  return a+b

# %%
hamna(3,3)
# Out:
# 6

# %%
def hamna(name="abcd"):
  print("hello",name)

# %%
hamna()
# Out:
# hello abcd
