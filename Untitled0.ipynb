# %% [markdown]
# <a href="https://colab.research.google.com/github/hamnafathimak/pythons1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temparature=30
if temparature>25:
    print ("it is a hot day")
else:
    print ("it is cold")
# Out:
# it is a hot day
